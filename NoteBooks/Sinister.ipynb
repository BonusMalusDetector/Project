# %%
#importation des librairies nécessaires
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
Sinistre_csv= pd.read_csv('Dataset/Sinistre.csv',sep=";")
Sinistres_xls = pd.read_excel('Dataset/Sinistres.xls')
# Out:
# /home/ayadi/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (12,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sSinistres_xls.shape
# Out:
# (24332, 9)

# %%
Sinistre_csv.shape
# Out:
# (560935, 20)

# %%
Sinistre_csv["date"].isnull().sum().sum()
# Out:
# 560935

# %%
Sinistre_csv.drop(columns=["date"],inplace=True)

# %%
Sinistre_csv.columns
# Out:
# Index(['sinistre_id', 'cga_police_id', 'cga_vehicule_id', 'cga_assure_id',
#        'numeroDuSinistre', 'dateDeSurvenanceDuSinistre',
#        'heureSurvanceDusinistre', 'dateOuvertureDuSinistre', 'lieuDuSinistre',
#        'identificationTiers', 'pourcentadeDeResponsabilite',
#        'numeroDePoliceCompagnieAdverse', 'codeCompagnieAdverse',
#        'porcentageCompagnieAdverse', 'numeroImmatriculationVehiculeAdverse',
#        'typeImmatriculationVehiculeAdverse', 'mouvementDusinistre',
#        'natureDuSinistre', 'Calculer_Sinistre'],
#       dtype='object')

# %%
Sinistres_xls.columns
# Out:
# Index(['sinistre_id', 'cga_police_id', 'cga_vehicule_id', 'cga_assure_id',
#        'dateOuvertureDuSinistre', 'lieuDuSinistre',
#        'pourcentadeDeResponsabilite', 'natureDuSinistre', 'Calculer_Sinistre'],
#       dtype='object')

# %%
Sinistres_xls.rename(columns={"CodeSinistre_id": "sinistre_id","CodePolice_id": "cga_police_id","CodeVehicule_id": "cga_vehicule_id","CodeAssure_id": "cga_assure_id",},inplace=True)

# %%
sinistre = pd.concat([Sinistre_csv, Sinistres_xls])

# %%
sinistre.head(2)
# Out:
#    sinistre_id  cga_police_id  cga_vehicule_id  cga_assure_id  \
# 0            2         174557           166073         144565
# 1            3         174557           166073         144565
#
#   numeroDuSinistre dateDeSurvenanceDuSinistre  heureSurvanceDusinistre  \
# 0       S170155501                 2017-12-18                      0.0
# 1       S180017071                 2018-02-16                      0.0
#
#   dateOuvertureDuSinistre lieuDuSinistre identificationTiers  \
# 0              2017-12-18            NaN                 NaN
# 1              2018-02-16            NaN                 NaN
#
#    pourcentadeDeResponsabilite numeroDePoliceCompagnieAdverse  \
# 0                            0                         834736
# 1                            0                            NaN
#
#    codeCompagnieAdverse  porcentageCompagnieAdverse  \
# 0                  11.0                         0.0
# 1                   1.0                         0.0
#
# ...

# %%
sinistre["lieuDuSinistreajuste"] = sinistre["lieuDuSinistre"]

# %%
len(sinistre["lieuDuSinistre"].unique())
# Out:
# 21858

# %%
sinistre['lieuDuSinistreajuste'] = sinistre['lieuDuSinistreajuste'].fillna("inconnu")
sinistre['lieuDuSinistreajuste'] = sinistre['lieuDuSinistreajuste'].str.lower()

# %%
data = {'Ville': ['tunis', 'beja' ,'ben arous' ,'bizerte', 'gabes' ,'gafsa' ,'jendouba', 'kairouan', 'kasserine', 'kebili' ,'kef' ,'mahdia', 'manouba', 'medenine', 'monastir' ,'nabeul' ,'sfax' ,'sidi bouzid', 'siliana' ,'sousse' ,'tataouine', 'tozeur', 'zaghouan','ariana','inconnu']}
Ville = pd.DataFrame(data,columns=['Ville'])

# %%
Ville.head(2)
# Out:
#    Ville
# 0  tunis
# 1   beja

# %%
for value in sinistre[~sinistre.lieuDuSinistreajuste.isin(Ville["Ville"])]["lieuDuSinistreajuste"]:
    for ville in Ville["Ville"]:
        if ville in value:
            sinistre.loc[(sinistre.lieuDuSinistreajuste ==value),'lieuDuSinistreajuste']=ville

# %%
len(sinistre["lieuDuSinistreajuste"].unique())
# Out:
# 10997

# %%
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mednine")),'lieuDuSinistreajuste']="medenine"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("la marsa")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rades")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bardo")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hammamet")),'lieuDuSinistreajuste']="nabeul"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("megrine")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("soukra")),'lieuDuSinistreajuste']="ariana"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ezzahra")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("route x")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("seliana")),'lieuDuSinistreajuste']="siliana"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el mourouj")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lac 2")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("grombalia")),'lieuDuSinistreajuste']="nabeul"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ennasr")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lac")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksar hellal")),'lieuDuSinistreajuste']="monastir"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("charguia")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mourouj")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("msaken")),'lieuDuSinistreajuste']="sousse"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("djerba")),'lieuDuSinistreajuste']="medenine"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("la soukra")),'lieuDuSinistreajuste']="ariana"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("carthage")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hammam lif")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lac 1")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jerba")),'lieuDuSinistreajuste']="medenine"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("b arous")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("le kram")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("borj louzir")),'lieuDuSinistreajuste']="ariana"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gammarth")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sahloul")),'lieuDuSinistreajuste']="sousse"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("marsa")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("centre urbain nord")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mnihla")),'lieuDuSinistreajuste']="ariana"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("korba")),'lieuDuSinistreajuste']="nabeul"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzah 6")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kebilli")),'lieuDuSinistreajuste']="kebili"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("la goulette")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kelibia")),'lieuDuSinistreajuste']="nabeul"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kram")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("charguia 1")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("boumhel")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mannouba")),'lieuDuSinistreajuste']="manouba"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzah 5")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("fouchana")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("les berges du lac")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzah 9")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el manar")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("denden")),'lieuDuSinistreajuste']="manouba"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ennasr 2")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("beni khiar")),'lieuDuSinistreajuste']="nabeul"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("aouina")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzel temime")),'lieuDuSinistreajuste']="nabeul"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mornag")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bab saadoun")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("le bardo")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("manar")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el menzah")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mornaguia")),'lieuDuSinistreajuste']="manouba"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mutuelle ville")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("montplaisir")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("moknine")),'lieuDuSinistreajuste']="monastir"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzah")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("midoun")),'lieuDuSinistreajuste']="medenine"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mannouba mannouba")),'lieuDuSinistreajuste']="manouba"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite olympique")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("raoued")),'lieuDuSinistreajuste']="ariana"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("laaouina")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite ezzouhour")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lafayette")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("charguia 2")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("laouina")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("oued ellil")),'lieuDuSinistreajuste']="manouba"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el omrane")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("akouda")),'lieuDuSinistreajuste']="sousse"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite ennasr")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("boumhal")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("dar chaabane")),'lieuDuSinistreajuste']="nabeul"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tabarka")),'lieuDuSinistreajuste']="jendouba"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sahline")),'lieuDuSinistreajuste']="monastir"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("place pasteur")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("l'aouina")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el fahs")),'lieuDuSinistreajuste']="zaghouan"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("zarzis")),'lieuDuSinistreajuste']="medenine"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ezzahrouni")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el menzah 9")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("moncef bey")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khaznadar")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lac2")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksar said")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi hassine")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("teboulba")),'lieuDuSinistreajuste']="monastir"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mutuelleville")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("zahrouni")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzah 8")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite ettahrir")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("metlaoui")),'lieuDuSinistreajuste']="gafsa"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bab alioua")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mourouj 1")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mateur")),'lieuDuSinistreajuste']="bizerte"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("manar 2")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("route de la marsa")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el menzah 6")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("borj cedria")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("houmt souk")),'lieuDuSinistreajuste']="medenine"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzah 1")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mareth")),'lieuDuSinistreajuste']="gabes"

sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp1")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite el khadhra")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sokra")),'lieuDuSinistreajuste']="ariana"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("safx")),'lieuDuSinistreajuste']="sfax"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ennaser")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el agba")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el mourouj 1")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("m'saken")),'lieuDuSinistreajuste']="sousse"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el manar 2")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el menzah 5")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mhamdia")),'lieuDuSinistreajuste']="ben arous"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lac1")),'lieuDuSinistreajuste']="tunis"
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzah")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzeh")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("manzah")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("manzeh")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lac")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("dria")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("aouina")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("manar")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("grombalia")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("marsa")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mourouj")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("charguia")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gazelle")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksour-essef")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("zahrouni")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bardo")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lafrane")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kassas")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kantaoui")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("moknine")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jemmel")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jemel")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouhjar")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lamta")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sayada")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("benbla")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bennane")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksiba")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bekalta")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("manzel harb")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ennasr")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("megrine")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("omran")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("route x")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("soukra")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mednine")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("carthage")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi daoued")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi daoud")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kalaa")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kala")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kala")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mghira")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksour essef")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hammamet")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hamamet")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hammamat")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ghazela")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ettadhamen")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ezzit")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("den den")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sijoumi")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("centre ville")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("morneg")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("medina")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khadra")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khezama")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("soliman")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("savary")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khadra")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("chaabene")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khaldoun")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("chaaben")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jammel")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("saadoun")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("carrefour")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("fouchena")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el jem")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ouardia")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("belvedere")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("parking")),'lieuDuSinistreajuste']='inconnu'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("autoroute")),'lieuDuSinistreajuste']='inconnu'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bousaid")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hammam chatt")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi rezig")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("av habib bourguiba")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("riadh el andalous")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("chotrana")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouzelfa")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("montfleury")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gremda")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hamma")),'lieuDuSinistreajuste']='gabes'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mornag")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("9 avril")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ibn sina")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("skhira")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("benguerdenne")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi hssine")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bou said")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("monplaisir")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tebourba")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("fadhal")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mellassine")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("naassen")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mehdia")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("nefza")),'lieuDuSinistreajuste']='beja'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bourguiba")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp9")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rte x")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rades")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("temime")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("midoun")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouargoub")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khalled")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("djerba")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khlifa")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("geant")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jemmal")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("fahs")),'lieuDuSinistreajuste']='zaghouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sejoumi")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("x20")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("xxx")),'lieuDuSinistreajuste']='inconnu'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("z4")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouficha")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kabaria")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("eljem")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gobain")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("barreket")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("zarzis")),'lieuDuSinistreajuste']='mednine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("zarsis")),'lieuDuSinistreajuste']='mednine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kassaa")),'lieuDuSinistreajuste']='sidi bouzid'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("x3")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksar hlel")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mohamed v")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mohamed 5")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("maamoura")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hergla")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jbel jloud")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp 1")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp1")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bembla")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi thabet")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mednine")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp8")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp 8")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("salambo")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ain zaghouen")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("agba")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kram")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rout x")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tazarka")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksar helal")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khadhra")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("douz")),'lieuDuSinistreajuste']='kebili'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("borj touil")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouhsina")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite erriadh")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("domicile")),'lieuDuSinistreajuste']='inconnu'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("yasminette")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kebeli")),'lieuDuSinistreajuste']='kebili'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gammart")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("andalous")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mjez el beb")),'lieuDuSinistreajuste']='beja'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ezzouhour")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("fayette")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("aeroport")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ras tabia")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mounastir")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("raoued")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jdaida")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("medjez el bab")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mediouni")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("eddaier")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouzid")),'lieuDuSinistreajuste']='sidi bouzid'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("denden")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bhar lazreg")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouhajla")),'lieuDuSinistreajuste']='kairouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("matmata")),'lieuDuSinistreajuste']='gabes'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el alia")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("enfidha")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("nasr")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("zahra")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("manzel chaker")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("x2")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("nfidha")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ghazala")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("chaker")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("beni khaled")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("intilaka")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sadoune")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("wardia")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cun")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("haouaria")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ras jebel")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp 9")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("borj el amri")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp9")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("routex")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hedi nouira")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("souassi")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("touzeur")),'lieuDuSinistreajuste']='tozeur'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mateur")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khenis")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mrezga")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bizert")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gamarth")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ras jebal")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("yasminet")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("korba")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jandouba")),'lieuDuSinistreajuste']='jendouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi mansour")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("alioua")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("el ain")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("chebba")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lakania")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("messaadine")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kasaa")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("nefta")),'lieuDuSinistreajuste']='tozeur'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("med v")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("metouia")),'lieuDuSinistreajuste']='gabes'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jarzouna")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tgm")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("zarzouna")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("skanes")),'lieuDuSinistreajuste']='monstir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mahrajene")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzel harb")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("slimen")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tahrir")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("republique")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bab bhar")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("dar chaabane")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi el heni")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ennasser")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("feriana")),'lieuDuSinistreajuste']='kasserine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("messadine")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kabariya")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bir ali")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("teniour")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("urbain nord")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ksar-hellal")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouzalfa")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sbitla")),'lieuDuSinistreajuste']='kasserine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mrezgua")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jedaida")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khzema")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("chbika")),'lieuDuSinistreajuste']='kairouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("nogra")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("nahli")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jloud")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("salah")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sokra")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sbikha")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bir el bey")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jam")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bousalem")),'lieuDuSinistreajuste']='jendouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ellile")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ghomrassen")),'lieuDuSinistreajuste']='tataouine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("temim")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite riadh")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("liberte")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("chatt meriem")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("etranger")),'lieuDuSinistreajuste']='inconnu'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi salem")),'lieuDuSinistreajuste']='beja'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi rzig")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rafraf")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tejerouine")),'lieuDuSinistreajuste']='kef'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi abdelhamid")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("houmet souk")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kheireddine")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tajerouine")),'lieuDuSinistreajuste']='kef'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("souika")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("farhat hached")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzel kamel")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi hsine")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("med 5")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("somaa")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("haffouz")),'lieuDuSinistreajuste']='kairouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("auto route")),'lieuDuSinistreajuste']='inconnu'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ain drahem")),'lieuDuSinistreajuste']='jendouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("madina jadida")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite essalama")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kelibia")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("cite jardin")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("gp5")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("oued elil")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("klibia")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kacem chebbi")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("passage")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("palestine")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("fathallah")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khniss")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("c u n")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khelidia")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rabta")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("birine")),'lieuDuSinistreajuste']='inconnu'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("boulila")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ouerdanine")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("grombelia")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mednin")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("teboursouk")),'lieuDuSinistreajuste']='beja'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rejiche")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bellevue")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bouselem")),'lieuDuSinistreajuste']='jendouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bab aliwa")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mellasine")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("saadallah")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("karkar")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("souk lahad")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("khezema")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("moknin")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("boumhel")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jelma")),'lieuDuSinistreajuste']='sidi bouzid'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("jbel ouest")),'lieuDuSinistreajuste']='zaghouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("m saken")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mjez el bab")),'lieuDuSinistreajuste']='beja'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi bou ali")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mnihla")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("rue de marseille")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("bir bouregba")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi bouali")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("boudriere")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tatouine")),'lieuDuSinistreajuste']='tataouine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("x 3")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("riadh el andalos")),'lieuDuSinistreajuste']='ariana'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hammmet")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("esperance")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi alouane")),'lieuDuSinistreajuste']='mahdia'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("fernana")),'lieuDuSinistreajuste']='jendouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("degueche")),'lieuDuSinistreajuste']='tozeur'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("alya")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("guerdane")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ouardanine")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("beni hassen")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("dahmani")),'lieuDuSinistreajuste']='kef'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("z 4")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sakit eddayer")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("menzel ennour")),'lieuDuSinistreajuste']='medenine'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("nasser")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("borj chakir")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("notre dame")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("allouche")),'lieuDuSinistreajuste']='nabeul'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("tborba")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("urbain")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mannouba")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("hicher")),'lieuDuSinistreajuste']='manouba'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("lif")),'lieuDuSinistreajuste']='ben arous'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("mahres")),'lieuDuSinistreajuste']='sfax'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("monstir")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("ras jbal")),'lieuDuSinistreajuste']='bizerte'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kairaouane")),'lieuDuSinistreajuste']='kairouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("sidi ameur")),'lieuDuSinistreajuste']='monastir'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kairaouane")),'lieuDuSinistreajuste']='kairouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kairaouan")),'lieuDuSinistreajuste']='kairouan'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("taieb mhiri")),'lieuDuSinistreajuste']='tunis'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("kondar")),'lieuDuSinistreajuste']='sousse'
sinistre.loc[(sinistre["lieuDuSinistreajuste"].str.contains("korbos")),'lieuDuSinistreajuste']='nabeul'

# %%
sinistre[~sinistre.lieuDuSinistreajuste.isin(Ville["Ville"])]["lieuDuSinistreajuste"].value_counts()
# Out:
# .                                 49
# /                                 24
# gorjani                            8
# corniche                           8
# naasen                             8
#                                   ..
# rue de stade municipale d elje     1
# rue chadli kalela                  1
# rue av alain savari rue amine      1
# rue ibn mandhour                   1
# rte g p 9                          1
# Name: lieuDuSinistreajuste, Length: 4734, dtype: int64

# %%
len(sinistre["lieuDuSinistreajuste"].unique())
# Out:
# 4759

# %%
#sinistre.to_csv("Dataset_clean/sinistre_clean.csv",index=False)

# %% [markdown]
# # Compiler à partir d'ici

# %% [markdown]
#             ***************************************************

# %%
sinistre_clean= pd.read_csv('Dataset_clean/sinistre_clean.csv',index_col=0)

# %%
#sinistre_clean.drop(columns=["Unnamed: 0"],inplace=True)

# %%
sinistre_clean.isnull().sum()
# Out:
# sinistre_id                                  0
# cga_police_id                                0
# cga_vehicule_id                              0
# cga_assure_id                                0
# numeroDuSinistre                         24332
# dateDeSurvenanceDuSinistre               24332
# heureSurvanceDusinistre                  24332
# dateOuvertureDuSinistre                      0
# lieuDuSinistre                          361882
# identificationTiers                     369844
# pourcentadeDeResponsabilite                  0
# numeroDePoliceCompagnieAdverse          380121
# codeCompagnieAdverse                    302615
# porcentageCompagnieAdverse               24332
# numeroImmatriculationVehiculeAdverse    364894
# typeImmatriculationVehiculeAdverse      358613
# mouvementDusinistre                      24332
# natureDuSinistre                             0
# Calculer_Sinistre                            0
# lieuDuSinistreajuste                         0
# dtype: int64

# %%
# supprimer la collonne null numeroDuSinistre
sinistre_clean=sinistre_clean.drop(columns="numeroDuSinistre")

# %%
# remplacer les valeurs null du dateDeSurvenanceDuSinistre par dateOuvertureDuSinistre
sinistre_clean['dateDeSurvenanceDuSinistre'] = sinistre_clean['dateDeSurvenanceDuSinistre'].fillna(sinistre_clean['dateOuvertureDuSinistre'])

# %%
sinistre_clean.isnull().sum()
# Out:
# sinistre_id                                  0
# cga_police_id                                0
# cga_vehicule_id                              0
# cga_assure_id                                0
# dateDeSurvenanceDuSinistre                   0
# heureSurvanceDusinistre                  24332
# dateOuvertureDuSinistre                      0
# lieuDuSinistre                          361882
# identificationTiers                     369844
# pourcentadeDeResponsabilite                  0
# numeroDePoliceCompagnieAdverse          380121
# codeCompagnieAdverse                    302615
# porcentageCompagnieAdverse               24332
# numeroImmatriculationVehiculeAdverse    364894
# typeImmatriculationVehiculeAdverse      358613
# mouvementDusinistre                      24332
# natureDuSinistre                             0
# Calculer_Sinistre                            0
# lieuDuSinistreajuste                         0
# dtype: int64

# %%
sinistre_clean["heureSurvanceDusinistre"].value_counts()
# Out:
# 0.0       376121
# 1.0       127380
# 1200.0      5487
# 1000.0      3419
# 1100.0      2399
#            ...
# 1149.0         1
# 1153.0         1
# 1156.0         1
# 435.0          1
# 2046.0         1
# Name: heureSurvanceDusinistre, Length: 725, dtype: int64

# %%
sinistre_clean["heureSurvanceDusinistreajuste"] = sinistre_clean["heureSurvanceDusinistre"]

# %%
sinistre_clean[sinistre_clean["heureSurvanceDusinistreajuste"]>100]["heureSurvanceDusinistreajuste"]
# Out:
# 11709     1200.0
# 11712     1030.0
# 11715     1500.0
# 11717     1800.0
# 11719      530.0
#            ...
# 560713    1000.0
# 560726    1130.0
# 560734    1800.0
# 560765    1300.0
# 560812    1000.0
# Name: heureSurvanceDusinistreajuste, Length: 57082, dtype: float64

# %%
sinistre_clean['heureSurvanceDusinistreajuste'] = sinistre_clean['heureSurvanceDusinistreajuste'].fillna(0)

# %%
sinistre_clean.loc[(sinistre_clean["heureSurvanceDusinistreajuste"]>100),'heureSurvanceDusinistreajuste']/=100

# %%
sinistre_clean["heureSurvanceDusinistreajuste"].value_counts()
# Out:
# 0.00     400453
# 1.00     127380
# 12.00      5492
# 10.00      3429
# 11.00      2403
#           ...
# 12.14         1
# 17.07         1
# 10.37         1
# 11.49         1
# 19.37         1
# Name: heureSurvanceDusinistreajuste, Length: 707, dtype: int64

# %%
sinistre_clean["heureSurvanceDusinistreajuste"].nunique()
# Out:
# 707

# %%
sinistre_clean["heureSurvanceDusinistreajuste"]=sinistre_clean["heureSurvanceDusinistreajuste"].round(0)

# %%
sinistre_clean[sinistre_clean["heureSurvanceDusinistreajuste"]>24].shape
# Out:
# (267, 20)

# %%
sinistre_clean.loc[(sinistre_clean["heureSurvanceDusinistreajuste"]>24),'heureSurvanceDusinistreajuste']/=10

# %%
sinistre_clean["heureSurvanceDusinistreajuste"]=sinistre_clean["heureSurvanceDusinistreajuste"].round(0)

# %%
sinistre_clean["heureSurvanceDusinistreajuste"].nunique()
# Out:
# 25

# %%
sinistre_clean["heureSurvanceDusinistreajuste"].value_counts()
# Out:
# 0.0     400453
# 1.0     127584
# 12.0     15150
# 10.0      5420
# 11.0      4006
# 16.0      3383
# 14.0      3273
# 8.0       3257
# 17.0      3190
# 15.0      3156
# 13.0      3045
# 9.0       2779
# 18.0      2460
# 19.0      1588
# 7.0       1430
# 20.0      1350
# 21.0       865
# 22.0       774
# 23.0       498
# 6.0        487
# 3.0        290
# 2.0        280
# 4.0        266
# 5.0        262
# 24.0        21
# Name: heureSurvanceDusinistreajuste, dtype: int64

# %%
sinistre_clean.isnull().sum()
# Out:
# sinistre_id                                  0
# cga_police_id                                0
# cga_vehicule_id                              0
# cga_assure_id                                0
# dateDeSurvenanceDuSinistre                   0
# heureSurvanceDusinistre                  24332
# dateOuvertureDuSinistre                      0
# lieuDuSinistre                          361882
# identificationTiers                     369844
# pourcentadeDeResponsabilite                  0
# numeroDePoliceCompagnieAdverse          380121
# codeCompagnieAdverse                    302615
# porcentageCompagnieAdverse               24332
# numeroImmatriculationVehiculeAdverse    364894
# typeImmatriculationVehiculeAdverse      358613
# mouvementDusinistre                      24332
# natureDuSinistre                             0
# Calculer_Sinistre                            0
# lieuDuSinistreajuste                         0
# heureSurvanceDusinistreajuste                0
# dtype: int64

# %%
sinistre_clean["pourcentadeDeResponsabilite"].value_counts()
# Out:
# 100    296537
# 0      268959
# 50      16882
# 200       582
# 90        541
# 80        406
# 25        339
# 70        303
# 150       223
# 75        222
# 120       142
# 140        53
# 170        33
# 250        27
# 160        11
# 300         6
# 350         1
# Name: pourcentadeDeResponsabilite, dtype: int64

# %%
sinistre_clean["fraud"]=sinistre_clean["pourcentadeDeResponsabilite"]

# %%
sinistre_clean["fraud"]=sinistre_clean["fraud"]*0

# %%
sinistre_clean["fraud"].unique()
# Out:
# array([0])

# %%
sinistre_clean.loc[(sinistre_clean["pourcentadeDeResponsabilite"]>100),'fraud']=1

# %%
sinistre_clean["fraud"].unique()
# Out:
# array([0, 1])

# %%
sinistre_clean["fraud"].value_counts()
# Out:
# 0    584189
# 1      1078
# Name: fraud, dtype: int64

# %%
# remplacer les valeurs null du dateDeSurvenanceDuSinistre par dateOuvertureDuSinistre
sinistre_clean['porcentageCompagnieAdverse'] = sinistre_clean['porcentageCompagnieAdverse'].fillna(100-sinistre_clean['pourcentadeDeResponsabilite'])

# %%
sinistre_clean["porcentageCompagnieAdverse"].value_counts()
# Out:
# 0.0      470764
# 100.0    107929
# 50.0       6276
# 75.0        188
# 25.0        110
# Name: porcentageCompagnieAdverse, dtype: int64

# %%
sinistre_clean[["porcentageCompagnieAdverse","pourcentadeDeResponsabilite"]]
# Out:
#        porcentageCompagnieAdverse  pourcentadeDeResponsabilite
# 0                             0.0                            0
# 1                             0.0                            0
# 2                             0.0                          100
# 3                             0.0                            0
# 4                             0.0                            0
# ...                           ...                          ...
# 24327                         0.0                          100
# 24328                         0.0                          100
# 24329                         0.0                          100
# 24330                       100.0                            0
# 24331                       100.0                            0
#
# [585267 rows x 2 columns]

# %%
sinistre_clean[["porcentageCompagnieAdverse","pourcentadeDeResponsabilite"]]
# Out:
#        porcentageCompagnieAdverse  pourcentadeDeResponsabilite
# 0                             0.0                            0
# 1                             0.0                            0
# 2                             0.0                          100
# 3                             0.0                            0
# 4                             0.0                            0
# ...                           ...                          ...
# 24327                         0.0                          100
# 24328                         0.0                          100
# 24329                         0.0                          100
# 24330                       100.0                            0
# 24331                       100.0                            0
#
# [585267 rows x 2 columns]

# %%
sinistre_clean[~(sinistre_clean["porcentageCompagnieAdverse"]+sinistre_clean["pourcentadeDeResponsabilite"]<=100)].shape
# Out:
# (12106, 21)

# %%
sinistre_clean
# Out:
#        sinistre_id  cga_police_id  cga_vehicule_id  cga_assure_id  \
# 0                2         174557           166073         144565
# 1                3         174557           166073         144565
# 2                4         174560            17936         119709
# 3                5         174573            17192         144580
# 4                6         174581           166084         135912
# ...            ...            ...              ...            ...
# 24327        24328         128293           123952         111772
# 24328        24329          66774            63542          58598
# 24329        24330         137856           133370         119314
# 24330        24331         129223           124871         112393
# 24331        24332          71277            68009          62671
#
#       dateDeSurvenanceDuSinistre  heureSurvanceDusinistre  \
# 0                     2017-12-18                      0.0
# ...

# %%
sinistre_clean["numeroDePoliceCompagnieAdverse"].nunique()
# Out:
# 175313

# %%
sinistre_clean.isnull().sum()
# Out:
# sinistre_id                                  0
# cga_police_id                                0
# cga_vehicule_id                              0
# cga_assure_id                                0
# dateDeSurvenanceDuSinistre                   0
# heureSurvanceDusinistre                  24332
# dateOuvertureDuSinistre                      0
# lieuDuSinistre                          361882
# identificationTiers                     369844
# pourcentadeDeResponsabilite                  0
# numeroDePoliceCompagnieAdverse          380121
# codeCompagnieAdverse                    302615
# porcentageCompagnieAdverse                   0
# numeroImmatriculationVehiculeAdverse    364894
# typeImmatriculationVehiculeAdverse      358613
# mouvementDusinistre                      24332
# natureDuSinistre                             0
# Calculer_Sinistre                            0
# lieuDuSinistreajuste                         0
# heureSurvanceDusinistreajuste                0
# ...

# %%
sinistre_clean['mois'] = pd.DatetimeIndex(sinistre_clean['dateOuvertureDuSinistre']).month

# %%
sinistre_clean['saison']=sinistre_clean['lieuDuSinistreajuste']
sinistre_clean['saison']=""

# %%
sinistre_clean
# Out:
#        sinistre_id  cga_police_id  cga_vehicule_id  cga_assure_id  \
# 0                2         174557           166073         144565
# 1                3         174557           166073         144565
# 2                4         174560            17936         119709
# 3                5         174573            17192         144580
# 4                6         174581           166084         135912
# ...            ...            ...              ...            ...
# 24327        24328         128293           123952         111772
# 24328        24329          66774            63542          58598
# 24329        24330         137856           133370         119314
# 24330        24331         129223           124871         112393
# 24331        24332          71277            68009          62671
#
#       dateDeSurvenanceDuSinistre  heureSurvanceDusinistre  \
# 0                     2017-12-18                      0.0
# ...

# %%
sinistre_clean.loc[(sinistre_clean["mois"].isin([3,4,5]) ),'saison']="printemps"
sinistre_clean.loc[(sinistre_clean["mois"].isin([6,7,8]) ),'saison']="ete"
sinistre_clean.loc[(sinistre_clean["mois"].isin([9,10,11]) ),'saison']="automne"
sinistre_clean.loc[(sinistre_clean["mois"].isin([12,1,2]) ),'saison']="hiver"

# %%
sinistre_clean["saison"].value_counts()
# Out:
# printemps    166039
# hiver        152372
# ete          134817
# automne      132039
# Name: saison, dtype: int64

# %%
listfraud = []

# %%
listfraud=sinistre_clean['cga_assure_id'].value_counts()[:50].index.tolist()

# %%
listfraud
# Out:
# [1426004,
#  1396434,
#  300600,
#  53968,
#  1535759,
#  113223,
#  63090,
#  55125,
#  54628,
#  62781,
#  1268823,
#  63302,
#  1505985,
#  140093,
#  36330,
#  68498,
#  1509263,
#  1511832,
#  144593,
#  1391871,
#  55412,
#  199128,
#  300935,
#  300754,
#  71676,
#  89878,
#  1424214,
#  52897,
#  1508258,
#  1268818,
#  416408,
#  138627,
#  53272,
#  1657634,
#  1104709,
#  313296,
#  1396418,
#  1508061,
#  1424221,
#  1424220,
#  1424234,
#  200462,
#  1109849,
#  301091,
#  1506907,
#  1517981,
#  93327,
#  1398753,
#  57959,
#  1268821]

# %%
sinistre_group=sinistre_clean.groupby("cga_vehicule_id")

# %%
sinistre_clean[sinistre_clean['cga_assure_id']==1426004]
# Out:
#         sinistre_id  cga_police_id  cga_vehicule_id  cga_assure_id  \
# 230579       365095        2615247           562279        1426004
# 230582       365098        2616543          1402385        1426004
# 230675       365192        2613274           574082        1426004
# 230686       365203        2613661           440041        1426004
# 230703       365220        2616074           458262        1426004
# ...             ...            ...              ...            ...
# 559987       736624        3325523           631594        1426004
# 560036       736673        3317449          1008592        1426004
# 560056       736693        2685869          1413521        1426004
# 560647       737284        2917322           764578        1426004
# 560718       737355        2680960          1200283        1426004
#
#        dateDeSurvenanceDuSinistre  heureSurvanceDusinistre  \
# 230579                 2018-03-06                      0.0
# ...

# %%
sinistre_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 585267 entries, 0 to 24331
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   sinistre_id                           585267 non-null  int64
#  1   cga_police_id                         585267 non-null  int64
#  2   cga_vehicule_id                       585267 non-null  int64
#  3   cga_assure_id                         585267 non-null  int64
#  4   dateDeSurvenanceDuSinistre            585267 non-null  object
#  5   heureSurvanceDusinistre               560935 non-null  float64
#  6   dateOuvertureDuSinistre               585267 non-null  object
#  7   lieuDuSinistre                        223385 non-null  object
#  8   identificationTiers                   215423 non-null  object
#  9   pourcentadeDeResponsabilite           585267 non-null  int64
# ...

# %%
sinistre_clean[sinistre_clean['cga_assure_id']==1268821]["dateDeSurvenanceDuSinistre"].value_counts()
# Out:
# 2017-05-25    3
# 2018-03-11    3
# 2019-03-06    3
# 2018-05-15    2
# 2018-05-10    2
#              ..
# 2019-02-10    1
# 2018-11-07    1
# 2018-07-06    1
# 2017-12-05    1
# 2019-03-25    1
# Name: dateDeSurvenanceDuSinistre, Length: 111, dtype: int64

# %%
sinistre_clean[sinistre_clean['cga_assure_id']==1396434]["dateDeSurvenanceDuSinistre"].value_counts()
# Out:
# 2018-06-11    11
# 2018-05-14    11
# 2018-03-05    10
# 2018-02-12    10
# 2018-02-23    10
#               ..
# 2019-07-11     1
# 2015-10-08     1
# 2019-07-27     1
# 2015-12-07     1
# 2016-03-15     1
# Name: dateDeSurvenanceDuSinistre, Length: 1073, dtype: int64

# %%
sinistre_clean["identificationTiers"].unique()
# Out:
# array([nan, 'A', 'V', 'I', 'U', 'P'], dtype=object)

# %%
sinistre_clean["lieuDuSinistreajuste"].value_counts()
# Out:
# inconnu                           362804
# tunis                              87265
# sfax                               24196
# ariana                             19258
# sousse                             16895
#                                    ...
# devant sale de fete antar - ga         1
# bir lehfey                             1
# route elain km 4                       1
# devant clinique exlence                1
# avenue taieb m'hiri                    1
# Name: lieuDuSinistreajuste, Length: 4759, dtype: int64

# %%
sinistre_clean.isnull().sum()
# Out:
# sinistre_id                                  0
# cga_police_id                                0
# cga_vehicule_id                              0
# cga_assure_id                                0
# dateDeSurvenanceDuSinistre                   0
# heureSurvanceDusinistre                  24332
# dateOuvertureDuSinistre                      0
# lieuDuSinistre                          361882
# identificationTiers                     369844
# pourcentadeDeResponsabilite                  0
# numeroDePoliceCompagnieAdverse          380121
# codeCompagnieAdverse                    302615
# porcentageCompagnieAdverse                   0
# numeroImmatriculationVehiculeAdverse    364894
# typeImmatriculationVehiculeAdverse      358613
# mouvementDusinistre                      24332
# natureDuSinistre                             0
# Calculer_Sinistre                            0
# lieuDuSinistreajuste                         0
# heureSurvanceDusinistreajuste                0
# ...

# %%
sinistre_clean["mouvementDusinistre"].unique()
# Out:
# array([ 2.,  3.,  1., nan])

# %%
sinistre_clean[sinistre_clean["pourcentadeDeResponsabilite"]>100]
# Out:
#         sinistre_id  cga_police_id  cga_vehicule_id  cga_assure_id  \
# 446189       622767        1582948           614530        1167980
# 446205       622783        1583240           614731        1168219
# 446211       622789        1583407           614844        1168335
# 446212       622790        1583411           614847        1168339
# 446234       622812        1585620          1079356        1170044
# ...             ...            ...              ...            ...
# 466344       642935        3574729          1316450        1754357
# 466348       642939        3575040           649272        1205607
# 466349       642940        3575106          1249336        1754513
# 466352       642943        3575250           460018        1754560
# 466355       642946        3575816           151764        1754804
#
#        dateDeSurvenanceDuSinistre  heureSurvanceDusinistre  \
# 446189                 2018-08-15                      0.0
# ...

# %%
sinistre_clean["cga_assure_id"].value_counts()
# Out:
# 1426004    6801
# 1396434    2538
# 300600     2219
# 53968      1623
# 1535759    1511
#            ...
# 401911        1
# 403958        1
# 399856        1
# 1202749       1
# 1048576       1
# Name: cga_assure_id, Length: 337120, dtype: int64

# %%
sinistre_clean.isnull().sum()
# Out:
# sinistre_id                                  0
# cga_police_id                                0
# cga_vehicule_id                              0
# cga_assure_id                                0
# dateDeSurvenanceDuSinistre                   0
# heureSurvanceDusinistre                  24332
# dateOuvertureDuSinistre                      0
# lieuDuSinistre                          361882
# identificationTiers                     369844
# pourcentadeDeResponsabilite                  0
# numeroDePoliceCompagnieAdverse          380121
# codeCompagnieAdverse                    302615
# porcentageCompagnieAdverse                   0
# numeroImmatriculationVehiculeAdverse    364894
# typeImmatriculationVehiculeAdverse      358613
# mouvementDusinistre                      24332
# natureDuSinistre                             0
# Calculer_Sinistre                            0
# lieuDuSinistreajuste                         0
# heureSurvanceDusinistreajuste                0
# ...

# %%
sinistre_clean.to_csv("Dataset_clean/sinistre_clean2.csv",index=False)

# %%
#new_sinistre["annee"]= pd.DatetimeIndex(new_sinistre['dateOuvertureDuSinistre']).year

# %%
#new_sinistre["annee"].value_counts()
