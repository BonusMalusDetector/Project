# %%
#importation des librairies nécessaires
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
weather1=pd.read_csv('weather1.csv')
weather2=pd.read_csv('weather2.csv')
weather3=pd.read_csv('weather_zarsis.csv')

# %%
weather1.shape
# Out:
# (12045, 9)

# %%
weather2.shape
# Out:
# (13140, 9)

# %%
weather3.shape
# Out:
# (1095, 9)

# %%
weather = pd.concat([weather1,weather2, weather3])

# %%
weather.shape
# Out:
# (26280, 9)

# %%
weather.head(3)
# Out:
#     lieu        date temperatureMaximale temperatureMinimale vitesseVent  \
# 0  Tunis  01/01/2017                 12°                 11°      12km/h
# 1  Tunis  02/01/2017                 14°                 11°       9km/h
# 2  Tunis  03/01/2017                 15°                 12°      23km/h
#
#   Humidite Visibilite                                etat ajuste
# 0      61%       10km                             Nuageux    0mm
# 1     10km         4%  Ciel dégagé  pleinement ensoleillé    63%
# 2      54%       10km     Soleil et partiellement nuageux    0mm

# %%
len(weather[weather.Visibilite.str.contains("%")]["Visibilite"])
# Out:
# 12335

# %%
weather.loc[(weather["Visibilite"].str.contains("%")),'Visibilite']=np.nan

# %%
weather["Visibilite"].isnull().sum()
# Out:
# 12335

# %%
# remplacer les valeurs null du Visibilite par Humidite
weather['Visibilite'] = weather['Visibilite'].fillna(weather['Humidite'])

# %%
weather["Visibilite"].isnull().sum()
# Out:
# 0

# %%
len(weather[weather.Visibilite.str.contains("%")]["Visibilite"])
# Out:
# 0

# %%
weather["Visibilite"]
# Out:
# 0          10km
# 1          10km
# 2          10km
# 3          10km
# 4       9.875km
#          ...
# 1090       10km
# 1091     9.75km
# 1092    9.875km
# 1093        9km
# 1094    8.875km
# Name: Visibilite, Length: 26280, dtype: object

# %%
len(weather[weather.Humidite.str.contains("km")]["Humidite"])
# Out:
# 12563

# %%
weather.loc[(weather["Humidite"].str.contains("km")),'Humidite']=np.nan

# %%
weather["Humidite"].isnull().sum()
# Out:
# 12563

# %%
# remplacer les valeurs null du Humidite par ajuste
weather['Humidite'] = weather['Humidite'].fillna(weather['ajuste'])

# %%
weather["Humidite"].isnull().sum()
# Out:
# 0

# %%
len(weather[weather.Humidite.str.contains("km")]["Humidite"])
# Out:
# 0

# %%
weather["Humidite"]
# Out:
# 0       61%
# 1       63%
# 2       54%
# 3       69%
# 4       62%
#        ...
# 1090    60%
# 1091    71%
# 1092    61%
# 1093    67%
# 1094    67%
# Name: Humidite, Length: 26280, dtype: object

# %%
weather.rename(columns={"ajuste": "Precipitations"},inplace=True)

# %%
#weather.drop(columns=["ajuste"],inplace=True)

# %%
weather.loc[(weather["Precipitations"].str.contains("%")),'Precipitations']=np.nan

# %%
weather
# Out:
#         lieu        date temperatureMaximale temperatureMinimale vitesseVent  \
# 0      Tunis  01/01/2017                 12°                 11°      12km/h
# 1      Tunis  02/01/2017                 14°                 11°       9km/h
# 2      Tunis  03/01/2017                 15°                 12°      23km/h
# 3      Tunis  04/01/2017                 15°                 14°      31km/h
# 4      Tunis  05/01/2017                 15°                 14°      52km/h
# ...      ...         ...                 ...                 ...         ...
# 1090  Zarzis  27/12/2019                 18°                 15°      10km/h
# 1091  Zarzis  28/12/2019                 17°                 15°      31km/h
# 1092  Zarzis  29/12/2019                 15°                 13°      34km/h
# 1093  Zarzis  30/12/2019                 13°                 11°      35km/h
# 1094  Zarzis  31/12/2019                 14°                 11°      33km/h
#
# ...

# %%
weather["temperatureMaximale"]
# Out:
# 0       12°
# 1       14°
# 2       15°
# 3       15°
# 4       15°
#        ...
# 1090    18°
# 1091    17°
# 1092    15°
# 1093    13°
# 1094    14°
# Name: temperatureMaximale, Length: 26280, dtype: object

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26280 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   lieu                 26280 non-null  object
#  1   date                 26280 non-null  object
#  2   temperatureMaximale  26280 non-null  object
#  3   temperatureMinimale  26280 non-null  object
#  4   vitesseVent          26280 non-null  object
#  5   Humidite             26280 non-null  object
#  6   Visibilite           26280 non-null  object
#  7   etat                 26280 non-null  object
#  8   Precipitations       13717 non-null  object
# dtypes: object(9)
# memory usage: 2.0+ MB

# %%
#sinistre_clean= pd.read_csv('../Dataset_clean/sinistre_clean_finale.csv')
sinistre_clean= pd.read_csv('../Dataset_clean/sinistre_clean_weather.csv')
# Out:
# /home/ayadi/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7,8,10,13,14,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sinistre_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 585267 entries, 0 to 585266
# Data columns (total 35 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   sinistre_id                           585267 non-null  int64
#  1   cga_police_id                         585267 non-null  int64
#  2   cga_vehicule_id                       585267 non-null  int64
#  3   cga_assure_id                         585267 non-null  int64
#  4   dateDeSurvenanceDuSinistre            585267 non-null  object
#  5   heureSurvanceDusinistre               560935 non-null  float64
#  6   dateOuvertureDuSinistre               585267 non-null  object
#  7   lieuDuSinistre                        223385 non-null  object
#  8   identificationTiers                   215423 non-null  object
#  9   pourcentadeDeResponsabilite           585267 non-null  int64
# ...

# %%
sinistre_clean['dateDeSurvenanceDuSinistre']=pd.to_datetime(sinistre_clean['dateDeSurvenanceDuSinistre'])

# %%
weather['date']=pd.to_datetime(weather['date'])

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26280 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lieu                      26280 non-null  object
#  1   date                      26280 non-null  datetime64[ns]
#  2   temperatureMaximale (°)   26280 non-null  int64
#  3   temperatureMinimale (°)   26280 non-null  int64
#  4   vitesseVent  (km/h)       26280 non-null  float64
#  5   Humidite (%)              26280 non-null  int64
#  6   Visibilite (km)           26280 non-null  float64
#  7   etat                      26280 non-null  object
#  8   Precipitations (mm)       26280 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(2)
# memory usage: 2.0+ MB

# %%
sinistre_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 585267 entries, 0 to 585266
# Data columns (total 35 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   sinistre_id                           585267 non-null  int64
#  1   cga_police_id                         585267 non-null  int64
#  2   cga_vehicule_id                       585267 non-null  int64
#  3   cga_assure_id                         585267 non-null  int64
#  4   dateDeSurvenanceDuSinistre            585267 non-null  datetime64[ns]
#  5   heureSurvanceDusinistre               560935 non-null  float64
#  6   dateOuvertureDuSinistre               585267 non-null  object
#  7   lieuDuSinistre                        223385 non-null  object
#  8   identificationTiers                   215423 non-null  object
#  9   pourcentadeDeResponsabilite           585267 non-null  int64
# ...

# %%
weather["lieu"].unique()
# Out:
# array(['tunis', 'nabeul', 'kebili', 'monastir', 'bizerte', 'kef', 'gabes',
#        'gafsa', 'mahdia', 'sfax', 'sousse', 'tataouine', 'jendouba',
#        'tozeur', 'beja', 'kairouan', 'kasserine', 'ben arous',
#        'sidi bouzid', 'zaghouan', 'siliana', 'Mateur', 'Carthage',
#        'medenine'], dtype=object)

# %%
weather.loc[weather["lieu"]=="Tunis",'lieu']="tunis"
weather.loc[weather["lieu"]=="Beja",'lieu']="beja"
weather.loc[weather["lieu"]=="Bizerte",'lieu']="bizerte"
weather.loc[weather["lieu"]=="El Kef",'lieu']="kef"
weather.loc[weather["lieu"]=="Gabès",'lieu']="gabes"
weather.loc[weather["lieu"]=="Gafsa",'lieu']="gafsa"
weather.loc[weather["lieu"]=="Mahdia",'lieu']="mahdia"
weather.loc[weather["lieu"]=="Sfax",'lieu']="sfax"
weather.loc[weather["lieu"]=="Sousse",'lieu']="sousse"
weather.loc[weather["lieu"]=="Tatouine",'lieu']="tataouine"
weather.loc[weather["lieu"]=="Tabarka",'lieu']="jendouba"
weather.loc[weather["lieu"]=="Tozeur",'lieu']="tozeur"
weather.loc[weather["lieu"]=="Kairouan",'lieu']="kairouan"
weather.loc[weather["lieu"]=="Kasserine",'lieu']="kasserine"
weather.loc[weather["lieu"]=="Rades",'lieu']="ben arous"
weather.loc[weather["lieu"]=="Sidi Bouzid",'lieu']="sidi bouzid"
weather.loc[weather["lieu"]=="Zaghouan",'lieu']="zaghouan"
weather.loc[weather["lieu"]=="Siliana",'lieu']="siliana"
weather.loc[weather["lieu"]=="Zarzis",'lieu']="medenine"
weather.loc[weather["lieu"]=="Nabeul",'lieu']="nabeul"
weather.loc[weather["lieu"]=="Kebili",'lieu']="kebili"
weather.loc[weather["lieu"]=="Monastir",'lieu']="monastir"

# %%
sinistre_clean["temperatureMaximale"]=""
sinistre_clean["temperatureMinimale"]=""
sinistre_clean["vitesseVent"]=""
sinistre_clean["Humidite"]=""
sinistre_clean["Visibilite"]=""
sinistre_clean["etat"]=""
sinistre_clean["Precipitations"]=""

# %%
weather
# Out:
#           lieu       date  temperatureMaximale (°)   temperatureMinimale (°)  \
# 0        tunis 2017-01-01                        12                       11
# 1        tunis 2017-02-01                        14                       11
# 2        tunis 2017-03-01                        15                       12
# 3        tunis 2017-04-01                        15                       14
# 4        tunis 2017-05-01                        15                       14
# ...        ...        ...                       ...                      ...
# 1090  medenine 2019-12-27                        18                       15
# 1091  medenine 2019-12-28                        17                       15
# 1092  medenine 2019-12-29                        15                       13
# 1093  medenine 2019-12-30                        13                       11
# 1094  medenine 2019-12-31                        14                       11
#
# ...

# %%
weather['temperatureMaximale']=weather['temperatureMaximale'].str.replace("°"," ")
weather['temperatureMinimale']=weather['temperatureMinimale'].str.replace("°"," ")
weather['vitesseVent']=weather['vitesseVent'].str.replace("km/h"," ")
weather['Humidite']=weather['Humidite'].str.replace("%"," ")
weather['Visibilite']=weather['Visibilite'].str.replace("km"," ")
weather['Precipitations']=weather['Precipitations'].str.replace("mm"," ")

# %%
 weather
# Out:
#           lieu       date  temperatureMaximale (°)   temperatureMinimale (°)  \
# 0        tunis 2017-01-01                        12                       11
# 1        tunis 2017-02-01                        14                       11
# 2        tunis 2017-03-01                        15                       12
# 3        tunis 2017-04-01                        15                       14
# 4        tunis 2017-05-01                        15                       14
# ...        ...        ...                       ...                      ...
# 1090  medenine 2019-12-27                        18                       15
# 1091  medenine 2019-12-28                        17                       15
# 1092  medenine 2019-12-29                        15                       13
# 1093  medenine 2019-12-30                        13                       11
# 1094  medenine 2019-12-31                        14                       11
#
# ...

# %%
weather['temperatureMaximale']=weather['temperatureMaximale'].astype(int)
weather['temperatureMinimale']=weather['temperatureMinimale'].astype(int)
weather['vitesseVent']=weather['vitesseVent'].astype(float)
weather['Humidite']=weather['Humidite'].astype(int)
weather['Visibilite']=weather['Visibilite'].astype(float)
weather['Precipitations']=weather['Precipitations'].astype(float)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26280 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   lieu                      26280 non-null  object
#  1   date                      26280 non-null  datetime64[ns]
#  2   temperatureMaximale (°)   26280 non-null  int64
#  3   temperatureMinimale (°)   26280 non-null  int64
#  4   vitesseVent  (km/h)       26280 non-null  float64
#  5   Humidite (%)              26280 non-null  int64
#  6   Visibilite (km)           26280 non-null  float64
#  7   etat                      26280 non-null  object
#  8   Precipitations (mm)       26280 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(2)
# memory usage: 2.0+ MB

# %%
weather.rename(columns={"temperatureMaximale": "temperatureMaximale (°) ","temperatureMinimale":"temperatureMinimale (°)","vitesseVent":"vitesseVent  (km/h)","Humidite":"Humidite (%)","Visibilite":"Visibilite (km)","Precipitations":"Precipitations (mm)"},inplace=True)

# %%
weather["Precipitations (mm)"].fillna(-1,inplace=True)

# %%
weather.isnull().sum().sum()
# Out:
# 0

# %%
weather
# Out:
#           lieu       date  temperatureMaximale (°)   temperatureMinimale (°)  \
# 0        tunis 2017-01-01                        12                       11
# 1        tunis 2017-02-01                        14                       11
# 2        tunis 2017-03-01                        15                       12
# 3        tunis 2017-04-01                        15                       14
# 4        tunis 2017-05-01                        15                       14
# ...        ...        ...                       ...                      ...
# 1090  medenine 2019-12-27                        18                       15
# 1091  medenine 2019-12-28                        17                       15
# 1092  medenine 2019-12-29                        15                       13
# 1093  medenine 2019-12-30                        13                       11
# 1094  medenine 2019-12-31                        14                       11
#
# ...

# %%
sinistre_clean[["dateDeSurvenanceDuSinistre","lieuDuSinistreajuste"]]
# Out:
#        dateDeSurvenanceDuSinistre lieuDuSinistreajuste
# 0                      2017-12-18              inconnu
# 1                      2018-02-16              inconnu
# 2                      2017-03-11              inconnu
# 3                      2017-11-23              inconnu
# 4                      2017-02-23              inconnu
# ...                           ...                  ...
# 585262                 2017-05-24              inconnu
# 585263                 2017-05-24              inconnu
# 585264                 2017-05-24              inconnu
# 585265                 2017-03-17              inconnu
# 585266                 2017-03-17              inconnu
#
# [585267 rows x 2 columns]

# %%
sinistre_clean_20 = sinistre_clean[sinistre_clean["lieuDuSinistreajuste"]!="inconnu"].sample(n=20)

# %%
weather.columns
# Out:
# Index(['lieu', 'date', 'temperatureMaximale (°) ', 'temperatureMinimale (°)',
#        'vitesseVent  (km/h)', 'Humidite (%)', 'Visibilite (km)', 'etat',
#        'Precipitations (mm)'],
#       dtype='object')

# %%
for value in sinistre_clean_20[["dateDeSurvenanceDuSinistre","lieuDuSinistreajuste"]].values:
    for weather_value in weather[["date","lieu","temperatureMaximale (°) ","temperatureMinimale (°)","vitesseVent  (km/h)","Humidite (%)","Visibilite (km)","etat","Precipitations (mm)"]].values:
        if (value[0]==weather_value[0] and value[1]==weather_value[1] ):
            sinistre_clean_20.loc[((sinistre_clean_20["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean_20["lieuDuSinistreajuste"]==value[1])),'temperatureMaximale']=weather_value[2]
            sinistre_clean_20.loc[((sinistre_clean_20["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean_20["lieuDuSinistreajuste"]==value[1])),'temperatureMinimale']=weather_value[3]
            sinistre_clean_20.loc[((sinistre_clean_20["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean_20["lieuDuSinistreajuste"]==value[1])),'vitesseVent']=weather_value[4]
            sinistre_clean_20.loc[((sinistre_clean_20["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean_20["lieuDuSinistreajuste"]==value[1])),'Humidite']=weather_value[5]
            sinistre_clean_20.loc[((sinistre_clean_20["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean_20["lieuDuSinistreajuste"]==value[1])),'Visibilite']=weather_value[6]
            sinistre_clean_20.loc[((sinistre_clean_20["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean_20["lieuDuSinistreajuste"]==value[1])),'etat']=weather_value[7]
            sinistre_clean_20.loc[((sinistre_clean_20["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean_20["lieuDuSinistreajuste"]==value[1])),'Precipitations']=weather_value[8]

# %%
sinistre_clean_20
# Out:
#         sinistre_id  cga_police_id  cga_vehicule_id  cga_assure_id  \
# 284996       435003        1833090           887265         862911
# 136932       214769        2070977          1307448        1342900
# 376163       548686        3172562           802792        1605509
# 386693       559748         404062           348094         335723
# 293640       444784        1249152          1001825         979117
# 34731         48761        1391109          1079267        1057930
# 77144        143863         186965           175314         156313
# 249541       384336         252090           190095         215917
# 362964       532875        2071085          1627529        1569898
# 41657         56032         408934           352330         339510
# 396613       571066        3401094           216420         203534
# 311570       464092        2609907           539152        1426004
# 24714         38582         235021           213538         200666
# ...

# %%
for value in sinistre_clean[(sinistre_clean["lieuDuSinistreajuste"]!="inconnu") & (sinistre_clean["temperatureMaximale"].isnull()) & (sinistre_clean["lieuDuSinistreajuste"].isin(weather["lieu"])) & (sinistre_clean["annee"]>2016) ][["dateDeSurvenanceDuSinistre","lieuDuSinistreajuste"]].values:
    for weather_value in weather[["date","lieu","temperatureMaximale (°) ","temperatureMinimale (°)","vitesseVent  (km/h)","Humidite (%)","Visibilite (km)","etat","Precipitations (mm)"]].values:
        if (value[0]==weather_value[0] and value[1]==weather_value[1] ):
            sinistre_clean.loc[((sinistre_clean["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean["lieuDuSinistreajuste"]==value[1])),'temperatureMaximale']=weather_value[2]
            sinistre_clean.loc[((sinistre_clean["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean["lieuDuSinistreajuste"]==value[1])),'temperatureMinimale']=weather_value[3]
            sinistre_clean.loc[((sinistre_clean["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean["lieuDuSinistreajuste"]==value[1])),'vitesseVent']=weather_value[4]
            sinistre_clean.loc[((sinistre_clean["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean["lieuDuSinistreajuste"]==value[1])),'Humidite']=weather_value[5]
            sinistre_clean.loc[((sinistre_clean["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean["lieuDuSinistreajuste"]==value[1])),'Visibilite']=weather_value[6]
            sinistre_clean.loc[((sinistre_clean["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean["lieuDuSinistreajuste"]==value[1])),'etat']=weather_value[7]
            sinistre_clean.loc[((sinistre_clean["dateDeSurvenanceDuSinistre"]==value[0]) & (sinistre_clean["lieuDuSinistreajuste"]==value[1])),'Precipitations']=weather_value[8]

# %%
sinistre_clean[~sinistre_clean["temperatureMaximale"].isnull()]
# Out:
#         sinistre_id  cga_police_id  cga_vehicule_id  cga_assure_id  \
# 11705         12356        1242974           996770         973598
# 11706         12357        1242983           996775         973607
# 11707         12358        1242986           996777         973610
# 11708         12359        1242987           996778         973611
# 11709         12360        1242991           996781         973615
# ...             ...            ...              ...            ...
# 581622        20688        1336876          1063119        1047098
# 581623        20689        1336467          1062803        1046760
# 581624        20690        1336477          1062811         976839
# 581625        20691        1336483          1062815         976836
# 581626        20692        1336484          1062816         976907
#
#        dateDeSurvenanceDuSinistre  heureSurvanceDusinistre  \
# 11705                  2018-01-23                      0.0
# ...

# %%
sinistre_clean[(sinistre_clean["lieuDuSinistreajuste"]!="inconnu") & (sinistre_clean["temperatureMaximale"].isnull()) & (sinistre_clean["lieuDuSinistreajuste"].isin(weather["lieu"])) & (sinistre_clean["annee"]>2016)][["dateDeSurvenanceDuSinistre","lieuDuSinistreajuste"]]
# Out:
# Empty DataFrame
# Columns: [dateDeSurvenanceDuSinistre, lieuDuSinistreajuste]
# Index: []

# %%
#sinistre_clean.to_csv("../Dataset_clean/sinistre_clean_weather.csv",index=False)

# %%
sinistre_clean[~sinistre_clean["lieuDuSinistreajuste"].isin(["inconnu","ben arous","monastir","nabeul","tunis","sfax","medenine","ariana","sousse","gabes"])]["lieuDuSinistreajuste"].value_counts()
# Out:
# bizerte                           3919
# manouba                           3270
# mahdia                            2975
# kairouan                          2391
# beja                              1985
#                                   ...
# ksour-essaf                          1
# av hopital militaire                 1
# rte elkalboussi menzel bouzelf       1
# gammerth                             1
# av 20 mars rue bechir tarmiz         1
# Name: lieuDuSinistreajuste, Length: 4749, dtype: int64

# %%
sinistre_clean["annee"].value_counts()
# Out:
# 2017    237998
# 2018    216134
# 2019    101615
# 2016     24777
# 2015      3599
# 2014       709
# 2013       205
# 2012        93
# 2011        44
# 2010        24
# 2009        22
# 2008        22
# 2007        13
# 2006         6
# 2004         2
# 2005         1
# 2003         1
# 1999         1
# 1995         1
# Name: annee, dtype: int64
